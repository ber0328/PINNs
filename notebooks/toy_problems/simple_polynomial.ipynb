# %% [markdown]
# **Najdi funkci $u$ na oblasti $\Omega = (0, 1) \times (0, 1)$ splňující:**
# $$\begin{align*}
#     -\Delta u &= f \qquad \text{na } \Omega \\
#     u &= 0 \qquad \text{na } \partial\Omega
# \end{align*}$$
#
# **Přesné řešení:**\
# Položme $u(x,y) = x(1-x)y(1-y)$. Snadno se ověří, že $u(x, y) = 0$ na $\partial\Omega$. Spočtěme Laplacián:
# $$\begin{equation*}
#     \Delta u = 2(x^2 + y^2 - x - y).
# \end{equation*}$$
# Volme funkci $f$ právě takto:
# $$\begin{equation*}
#     f(x, y) = -2(x^2 + y^2 - x - y).
# \end{equation*}$$
# Z toho je již však vidno, že dvojice $u, f$ je přesným řešením úlohy. \
# Níže budeme trénovat model řešící tuto úlohu, a poté jej porovnáme s přesným řešením.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Zakladni import
import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
import numpy as np
import sys

# %%
# Import vlastnich modulu
sys.path.append('../..')
import src.models.mlp_model as mm
import src.data.cube_domain as cb
from src import train
from src import calculus as calc
from src import utils

# %%
# Volba vhodneho device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# definice funkce f(x, y)
def f(x: torch.Tensor) -> torch.Tensor:
    return -2 * (x[:, 0:1]**2 + x[:, 1:2]**2 - x[:, 0:1] - x[:, 1:2])

def exact_solution(x: torch.Tensor) -> torch.Tensor:
    return x[:, 0:1]*(1 - x[:, 0:1])*x[:, 1:2]*(1 - x[:, 1:2])

# %%
# Definice ztratove funkce
def loss_fn(model: nn.Module, domain: cb.CubeDomain) -> torch.Tensor:
    # ztrata na vnitrku:
    interior_input = domain.interior.requires_grad_(True)
    interior_output = model(interior_input)
    u_lapl = calc.laplacian(interior_input, interior_output, device, False)
    # print(u_lapl)
    # _, _, _, _, _, u_lapl = calc.laplacian_2d(model, domain.interior)
    # print(u_lapl)
    f_vals = f(domain.interior)
    inner_loss = torch.mean((u_lapl + f_vals) ** 2)
    
    total_bnd = torch.cat((domain.sides[0][0], domain.sides[0][1],
                           domain.sides[1][0], domain.sides[1][1]), dim=0)

    u_bnd = model(total_bnd)
    bnd_loss = torch.mean((u_bnd) ** 2)

    return [inner_loss, bnd_loss]

def l2_loss(model: nn.Module, domain: cb.CubeDomain) -> torch.Tensor:
    return [calc.L2_norm(model, exact_solution, 2, domain.ctx.u_bounds, domain.ctx.l_bounds, device=domain.ctx.device, n=100)]

# %%
# Definice domeny
config = cb.CubeContext(
    dim = 2,
    l_bounds=[0, 0],
    u_bounds=[1, 1],
    N_int=2_000,
    N_sides=[(100, 100), (100, 100)],
    device=device
)

model_ctx = mm.ModelContext(
    input_dim=2,
    output_dim=1,
    layer=[64, 64, 64],
    u_bounds=[1, 1],
    l_bounds=[0, 0],
    last_layer_activation='sinn')

domain = cb.CubeDomain(config)
# Definice modelu
model = mm.MLPModel(model_ctx).to(device)
# Definice optimizeru
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# Definice scheduleru
scheduler = ReduceLROnPlateau(optimizer, factor=0.5, patience=500)
domain.generate_points()

# %%
# Spusteni trenovani
context = train.TrainingContext(
    model=model,
    optimizer=optimizer,
    domain=domain,
    loss_fn=l2_loss,
    scheduler=scheduler,
    epochs=5_000,
    monitor_lr=True
)

loss_values = train.train_switch_to_lbfgs(ctx=context, lbfgs_lr=0.1)
# Out:
# Loss at epoch 1 is: 0.0737662985920906. Current learing rate: 0.001
# Loss at epoch 100 is: 0.003244528081268072. Current learing rate: 0.001
# Loss at epoch 200 is: 0.003349347971379757. Current learing rate: 0.001
# Loss at epoch 300 is: 0.003035074332728982. Current learing rate: 0.001
# Loss at epoch 400 is: 0.0026725688949227333. Current learing rate: 0.001
# Loss at epoch 500 is: 0.002483118325471878. Current learing rate: 0.001
# Loss at epoch 600 is: 0.0022578753996640444. Current learing rate: 0.001
# Loss at epoch 700 is: 0.0021356334909796715. Current learing rate: 0.001
# Loss at epoch 800 is: 0.002048454014584422. Current learing rate: 0.001
# Loss at epoch 900 is: 0.0019715295638889074. Current learing rate: 0.001
# Loss at epoch 1000 is: 0.0018655200256034732. Current learing rate: 0.001
# Loss at epoch 1100 is: 0.001817934913560748. Current learing rate: 0.001
# Loss at epoch 1200 is: 0.0017717914888635278. Current learing rate: 0.001
# Loss at epoch 1300 is: 0.001740807550959289. Current learing rate: 0.001
# Loss at epoch 1400 is: 0.0016963512171059847. Current learing rate: 0.001
# Loss at epoch 1500 is: 0.0016568785067647696. Current learing rate: 0.001
# Loss at epoch 1600 is: 0.001627821009606123. Current learing rate: 0.001
# Loss at epoch 1700 is: 0.0016027750680223107. Current learing rate: 0.001
# Loss at epoch 1800 is: 0.0015721524832770228. Current learing rate: 0.001
# Loss at epoch 1900 is: 0.0015436455141752958. Current learing rate: 0.001
# Loss at epoch 2000 is: 0.0015244092792272568. Current learing rate: 0.001
# Loss at epoch 2100 is: 0.0015058254357427359. Current learing rate: 0.001
# Loss at epoch 2200 is: 0.0014874021289870143. Current learing rate: 0.001
# Loss at epoch 2300 is: 0.001481186249293387. Current learing rate: 0.001
# Loss at epoch 2400 is: 0.0014424496330320835. Current learing rate: 0.001
# Loss at epoch 2500 is: 0.001423464622348547. Current learing rate: 0.001
# Loss at epoch 2600 is: 0.0014065478462725878. Current learing rate: 0.001
# Loss at epoch 2700 is: 0.0013623451814055443. Current learing rate: 0.001
# Loss at epoch 2800 is: 0.001362967654131353. Current learing rate: 0.001
# Loss at epoch 2900 is: 0.0013440331676974893. Current learing rate: 0.001
# Loss at epoch 3000 is: 0.0013440613402053714. Current learing rate: 0.001
# Loss at epoch 3100 is: 0.0013111241860315204. Current learing rate: 0.001
# Loss at epoch 3200 is: 0.0013006579829379916. Current learing rate: 0.001
# Loss at epoch 3300 is: 0.001273634727112949. Current learing rate: 0.001
# Loss at epoch 3400 is: 0.0012763716513291001. Current learing rate: 0.001
# Loss at epoch 3500 is: 0.001243180246092379. Current learing rate: 0.001
# Loss at epoch 3600 is: 0.0012148992391303182. Current learing rate: 0.001
# Loss at epoch 3700 is: 0.001225346582941711. Current learing rate: 0.001
# Loss at epoch 3800 is: 0.001201158738695085. Current learing rate: 0.001
# Loss at epoch 3900 is: 0.0011637264396995306. Current learing rate: 0.001
# Loss at epoch 4000 is: 0.0011606821790337563. Current learing rate: 0.001
# Loss at epoch 4100 is: 0.0011632215464487672. Current learing rate: 0.001
# Loss at epoch 4200 is: 0.001127142459154129. Current learing rate: 0.001
# Loss at epoch 4300 is: 0.0011487406445667148. Current learing rate: 0.001
# Loss at epoch 4400 is: 0.001099182409234345. Current learing rate: 0.001
# Loss at epoch 4500 is: 0.001093035563826561. Current learing rate: 0.001
# Loss at epoch 4600 is: 0.001093826605938375. Current learing rate: 0.001
# Loss at epoch 4700 is: 0.00106560077983886. Current learing rate: 0.001
# Loss at epoch 4800 is: 0.001088649034500122. Current learing rate: 0.001
# Loss at epoch 4900 is: 0.0010438829194754362. Current learing rate: 0.001
# Loss at epoch 5000 is: 0.0010033538565039635. Current learing rate: 0.001
# Switching to LBFGS
# Loss at lbfgs-epoch 100 is: 0.0001738593855407089
# Loss at lbfgs-epoch 200 is: 0.00015940636512823403
# Loss at lbfgs-epoch 300 is: 0.00015940636512823403
# Loss at lbfgs-epoch 400 is: 0.00015940636512823403
# Loss at lbfgs-epoch 500 is: 0.00015940636512823403

# %%
# Vykresleni ztraty
plot_ctx = utils.PlotContext(
    u_bounds=domain.ctx.u_bounds,
    l_bounds=domain.ctx.l_bounds,
    device=device,
    patches=[],
    figsize=(5, 4),
    vmin=0.0,
    vmax=0.06,
    N=100,
    titles=["Loss values"],
    x_label='Epochs',
    y_label='Loss',
    function_names=['u']
)

utils.plot_loss_values({"Total loss": loss_values[0]}, plot_ctx=plot_ctx)
# Out:
# /home/berva/Projects2/Projects/PINNs/Introduction/notebooks/../src/utils.py:61: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_x_labels)

# %%
# Kontrola vysledku
# prvne vykreslime trenovaci ztratu
plot_ctx.figsize = (18, 6)
plot_ctx.x_label = "x"
plot_ctx.y_label = "y"
plot_ctx.vmax = 0.06
plot_ctx.fontsize = 16
plot_ctx.titles = ["Learned solution", "Exact solution"]
plot_ctx.function_names = ['u', 'u']

utils.plot_function_on_2d_cube([model, exact_solution], plot_ctx)

# %%
# Nyni vykreslime spravne reseseni
plot_ctx.figsize = (6, 4)
plot_ctx.vmax = 0.00001
plot_ctx.titles = ["Absolute error"]
plot_ctx.function_names = ['error']

utils.plot_function_on_2d_cube([lambda x: torch.abs(model(x) - exact_solution(x))], plot_ctx)

# %%
# a spocteme l2 normu rozdilu odhadu a skutecneho reseni
norm = calc.L2_norm(model, exact_solution, 2, [0, 0], [1, 1], device, n=100)
print(f"L2 norma je: {norm}")
# Out:
# L2 norma je: 0.0001594062923686579
