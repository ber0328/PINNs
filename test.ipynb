# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from src.models.convection import ConvectionModel
from src.data.square_domain import SquareDomain2D
from src.train import train_conv_model
from numpy import pi
import src.utils as ut

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model = ConvectionModel().to(device)
domain = SquareDomain2D(0, 2 * pi, 0, 1)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, eps=0.001, amsgrad=True)

# %%
train_conv_model(model, optimizer, domain, 10, epochs=10000, N=1000)
# Out:
# Loss at epoch 100 is: 0.746956467628479
# Loss at epoch 200 is: 0.6467053890228271
# Loss at epoch 300 is: 0.5756903290748596
# Loss at epoch 400 is: 0.5503665208816528
# Loss at epoch 500 is: 0.4899710416793823
# Loss at epoch 600 is: 0.4727228879928589
# Loss at epoch 700 is: 0.44851261377334595
# Loss at epoch 800 is: 0.4155210256576538
# Loss at epoch 900 is: 0.3823973536491394
# Loss at epoch 1000 is: 0.3472317159175873
# Loss at epoch 1100 is: 0.31864696741104126
# Loss at epoch 1200 is: 0.2851980924606323
# Loss at epoch 1300 is: 0.25600939989089966
# Loss at epoch 1400 is: 0.2069018930196762
# Loss at epoch 1500 is: 0.18027639389038086
# Loss at epoch 1600 is: 0.14569365978240967
# Loss at epoch 1700 is: 0.13148793578147888
# Loss at epoch 1800 is: 0.1103329211473465
# Loss at epoch 1900 is: 0.09320136904716492
# Loss at epoch 2000 is: 0.07939697057008743
# Loss at epoch 2100 is: 0.06385896354913712
# Loss at epoch 2200 is: 0.0579497255384922
# ...

# %%
ut.graph_prediction(model, domain)

# %%
torch.save(model.state_dict(), "./model_6_x_20.pt")
